# %%
x = 12

# %%
print(x)
print(~x)
# Out:
# 12
# -13

# %%
# Identity Operator - compares memory locations of 2 objects
is => evaluates to True if the variables point to the same object, False otherwise
is not => evaluates to False if the variables point to the same object, True otherwise

# %%
a = 20 
b = 20 
print(id(a))
print(id(b))
# Out:
# 11761288
# 11761288

# %%
c = 10
print(id(c))
# Out:
# 11760968

# %%
print(a is b)
# Out:
# True

# %%
print (a is not b)
# Out:
# False

# %%
print(a is c)
# Out:
# False

# %%
print(b is not c)
# Out:
# True

# %%
# Accepting Data from user 
x = input()
print(x)
# Out:
# faheem
# faheem

# %%
x = input("Enter a value")
print(x)
# Out:
# Enter a value20
# 20

# %%
x = input('Enter your name')
print('welcome', x)
# Out:
# Enter your namefaheem
# welcome faheem

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 print(type(x))
# ----> 2 print(type(y))
#
# NameError: name 'y' is not defined

# %%
x = int(input("Enter a value"))
y = int(input("enter another value"))


z = x + y

print(z)
# Out:
# Enter a value25
# enter another value30
# 55

# %%
x = int(input("enter a value"))

y = x*x*x

print(y)
# Out:
# enter a value2
# 8
