# %%
a = 20 
b = 20

# %%
print(a<=b)
print(a>=b)
# Out:
# True
# True

# %%
Logical Operators: used to combine multiple conditions
and - if both the conditions are true only then the result is True 
or - if any one condition is True the result is True not - negates a condition (reverse logical state of a given condition)
# Out:
#   Cell In[3], line 1
#     Logical Operators: used to combine multiple conditions
#             ^
# SyntaxError: invalid syntax

# %%
a = 10
b = 20 
c = 30

# %%
a < b
# Out:
# True

# %%
c > b
# Out:
# True

# %%
a < b and c > b
# Out:
# True

# %%
a < b and c > b
# Out:
# True

# %%
b < c
# Out:
# True

# %%
a < b and b > c
# Out:
# False

# %%
not(a > b or b < c)
# Out:
# False

# %%
a < b and b < c
# Out:
# True

# %%
a<b<c
# Out:
# True

# %%
a<b<c # same as a<b and B<c. Known as chaining
# Out:
# True

# %%
Assignment Operators
= 
+=
*=
    /=
    %= 
    //= 
    **=
# Out:
#   Cell In[16], line 1
#     Assignment Operators
#                ^
# SyntaxError: invalid syntax

# %%
a=5
print(a)
# Out:
# 5

# %%
a=a+10 # a = a +10
print(a)
# Out:
# 15

# %%
a-=10
print (a) 
# a = a -4
# Out:
# -35

# %%
a*=5

# %%
BITWISE OPERATORS :
    & BITWISE AND
    | BITWISE OR
    ^ BITWISE XOR
    ~ Bitwise XOR
    << Bitwise one's compliment
    << bitwise left shift
    >> bitwise right shift
# Out:
#   Cell In[23], line 6
#     << Bitwise one's compliment
#                   ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
a = 60
b = 13

# %%
print(bin(60))
print(bin(13))
# Out:
# 0b111100
# 0b1101

# %%
a & b
#
#
# Out:
# 12

# %%
#111100
#001101
#001100

# %%
a | b
# Out:
# 61

# %%
a ^ b
# Out:
# 49

# %%
s = "Hello"

# %%
print("H" in s)
# Out:
# True

# %%
print("ell" in s)
# Out:
# True

# %%
print("w" in s)
# Out:
# False

# %%
print("W" not in s)
# Out:
# True
